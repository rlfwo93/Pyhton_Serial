# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a2 = "C:/Users/ParkJinSeok/Desktop/지도샘플/HDMap_UTM52N_mini_20210726v1/A2_LINK.shp"

ra2 = gpd.read_file(a2)

ra2
# Out:
#               ID AdminCode RoadRank RoadType RoadNo LinkType  MaxSpeed  \
# 0   A219AS302211       413        6        1   None        6        40
# 1   A219AS302212       413        6        1   None        6        40
# 2   A219AS302213       413        6        1   None        6        40
# 3   A219AS302214       413        6        1   None        6        40
# 4   A219AS302215       413        6        1   None        6        40
# 5   A219AS302216       413        6        1   None        6        40
# 6   A219AS302217       413        6        1   None        6        40
# 7   A219AS302218       413        6        1   None        6        40
# 8   A219AS302791       413        6        1   None        1        30
# 9   A219AS302792       413        6        1   None        1        30
# 10  A219AS302793       413        6        1   None        1        30
# 11  A219AS302794       413        6        1   None        1        30
# ...

# %%
ra2.plot()
# Out:
# <AxesSubplot:>

# %%
a2g = "C:/Users/ParkJinSeok/Desktop/지도샘플/HDMap_UTM52N_mini_20210726v1/GridID/GridID.shp"

a2gr = gpd.read_file(a2g) 

a2gr
# Out:
#            id      left         top     right      bottom  \
# 0   1035988.0  343896.8  4042945.98  344146.8  4042695.98
# 1   1035989.0  343896.8  4042695.98  344146.8  4042445.98
# 2   1035990.0  343896.8  4042445.98  344146.8  4042195.98
# 3   1035991.0  343896.8  4042195.98  344146.8  4041945.98
# 4   1035992.0  343896.8  4041945.98  344146.8  4041695.98
# ..        ...       ...         ...       ...         ...
# 94  1055386.0  345896.8  4041445.98  346146.8  4041195.98
# 95  1055387.0  345896.8  4041195.98  346146.8  4040945.98
# 96  1055388.0  345896.8  4040945.98  346146.8  4040695.98
# 97  1055389.0  345896.8  4040695.98  346146.8  4040445.98
# 98  1055390.0  345896.8  4040445.98  346146.8  4040195.98
#
#                                              geometry
# 0   POLYGON ((343896.800 4042945.980, 344146.800 4...
# 1   POLYGON ((343896.800 4042695.980, 344146.800 4...
# 2   POLYGON ((343896.800 4042445.980, 344146.800 4...
# ...

# %%
# Out:
# <AxesSubplot:>
