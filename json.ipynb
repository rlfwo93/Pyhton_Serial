# %%
import json

txt_f = "C:/Users/ParkJinSeok/Desktop/지도샘플/점,면,선/sss.txt"


linet = []

with open(txt_f,"rb") as fh:
    lines = fh.readlines()
    for line in lines:
        line = line.decode()
        linet.append(line[:len(line)-3])
        print(line)
# Out:
# X = 344272.812396
#
# Y = 4041070.301697
#
# Z = 55.770500
#
# X = 344272.586096
#
# Y = 4041070.326197
#
# Z = 55.768126
#
# X = 344272.352896
#
# Y = 4041070.362197
#
# Z = 55.767326
#
# X = 344271.986796
#
# Y = 4041070.453097
#
# Z = 55.762826
#
# X = 344271.628996
#
# Y = 4041070.561097
#
# Z = 55.761226
#
# X = 344271.442995
#
# Y = 4041070.620597
#
# Z = 55.760626
#
# X = 344271.084595
#
# Y = 4041070.766697
#
# Z = 55.763227
#
# X = 344268.967696
#
# Y = 4041071.607797
#
# Z = 55.755127
#
# X = 344268.058396
#
# Y = 4041071.966397
#
# Z = 55.751826
#
# X = 344266.558695
#
# Y = 4041072.572497
#
# Z = 55.736227
#
# X = 344263.770487
#
# Y = 4041073.679526
#
# Z = 55.716624
#
# X = 344263.457996
#
# Y = 4041073.803597
#
# Z = 55.714426
#
# X = 344262.137395
#
# Y = 4041074.318097
#
# Z = 55.702026
#
# X = 344261.045096
#
# Y = 4041074.758397
#
# Z = 55.692126
#
# X = 344259.625195
#
# Y = 4041075.322897
#
# Z = 55.683827
#
# X = 344258.515995
#
# Y = 4041075.760297
#
# ...

# %%
with
# Out:
# ['X = 344272.812396',
#  'Y = 4041070.301697',
#  'Z = 55.770500',
#  'X = 344272.586096',
#  'Y = 4041070.326197',
#  'Z = 55.768126',
#  'X = 344272.352896',
#  'Y = 4041070.362197',
#  'Z = 55.767326',
#  'X = 344271.986796',
#  'Y = 4041070.453097',
#  'Z = 55.762826',
#  'X = 344271.628996',
#  'Y = 4041070.561097',
#  'Z = 55.761226',
#  'X = 344271.442995',
#  'Y = 4041070.620597',
#  'Z = 55.760626',
#  'X = 344271.084595',
#  'Y = 4041070.766697',
#  'Z = 55.763227',
#  'X = 344268.967696',
#  'Y = 4041071.607797',
#  'Z = 55.755127',
#  'X = 344268.058396',
#  'Y = 4041071.966397',
#  'Z = 55.751826',
#  'X = 344266.558695',
#  'Y = 4041072.572497',
#  'Z = 55.736227',
#  'X = 344263.770487',
#  'Y = 4041073.679526',
#  'Z = 55.716624',
#  'X = 344263.457996',
#  'Y = 4041073.803597',
#  'Z = 55.714426',
#  'X = 344262.137395',
#  'Y = 4041074.318097',
#  'Z = 55.702026',
#  'X = 344261.045096',
#  'Y = 4041074.758397',
#  'Z = 55.692126',
#  'X = 344259.625195',
# ...

# %%
# KEY,VALUE 값 추출

kv = []
vv = []

for i in range(len(linet)):
    kv.append(linet[i][0])
    vv.append(linet[i][4:])

for i in range(len(vv)):
    vv[i] = float(vv[i])

kv
# Out:
# ['X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z',
#  'X',
#  'Y',
#  'Z']

# %%
vv
# Out:
# [344272.812396,
#  4041070.301697,
#  55.7705,
#  344272.586096,
#  4041070.326197,
#  55.768126,
#  344272.352896,
#  4041070.362197,
#  55.767326,
#  344271.986796,
#  4041070.453097,
#  55.762826,
#  344271.628996,
#  4041070.561097,
#  55.761226,
#  344271.442995,
#  4041070.620597,
#  55.760626,
#  344271.084595,
#  4041070.766697,
#  55.763227,
#  344268.967696,
#  4041071.607797,
#  55.755127,
#  344268.058396,
#  4041071.966397,
#  55.751826,
#  344266.558695,
#  4041072.572497,
#  55.736227,
#  344263.770487,
#  4041073.679526,
#  55.716624,
#  344263.457996,
#  4041073.803597,
#  55.714426,
#  344262.137395,
#  4041074.318097,
#  55.702026,
#  344261.045096,
#  4041074.758397,
#  55.692126,
#  344259.625195,
#  4041075.322897,
#  55.683827,
#  344258.515995,
#  4041075.760297,
#  55.679027,
#  344257.371295,
#  4041076.220397,
#  55.677527,
#  344256.196596,
#  4041076.675997,
#  55.661527,
#  344253.416014,
#  4041077.802055,
#  55.64262,
#  344252.858095,
# ...

# %%
#JSON형식으로 변환 1.
M = dict(zip(range(1, len(vv) + 1), vv))
js = json.dumps(M)  # JSON형식으로 변환 함수
js


dict{}
# Out:
# '{"1": 344272.812396, "2": 4041070.301697, "3": 55.7705, "4": 344272.586096, "5": 4041070.326197, "6": 55.768126, "7": 344272.352896, "8": 4041070.362197, "9": 55.767326, "10": 344271.986796, "11": 4041070.453097, "12": 55.762826, "13": 344271.628996, "14": 4041070.561097, "15": 55.761226, "16": 344271.442995, "17": 4041070.620597, "18": 55.760626, "19": 344271.084595, "20": 4041070.766697, "21": 55.763227, "22": 344268.967696, "23": 4041071.607797, "24": 55.755127, "25": 344268.058396, "26": 4041071.966397, "27": 55.751826, "28": 344266.558695, "29": 4041072.572497, "30": 55.736227, "31": 344263.770487, "32": 4041073.679526, "33": 55.716624, "34": 344263.457996, "35": 4041073.803597, "36": 55.714426, "37": 344262.137395, "38": 4041074.318097, "39": 55.702026, "40": 344261.045096, "41": 4041074.758397, "42": 55.692126, "43": 344259.625195, "44": 4041075.322897, "45": 55.683827, "46": 344258.515995, "47": 4041075.760297, "48": 55.679027, "49": 344257.371295, "50": 4041076.220397, "51"
# ...

# %%
#JSON형식으로 변환 2.

di=[]
for i in range(len(kv)):
    di.append({kv[i]:vv[i]})
    
    
dis = json.dumps(di)

dis
# Out:
# '[{"X": 344272.812396}, {"Y": 4041070.301697}, {"Z": 55.7705}, {"X": 344272.586096}, {"Y": 4041070.326197}, {"Z": 55.768126}, {"X": 344272.352896}, {"Y": 4041070.362197}, {"Z": 55.767326}, {"X": 344271.986796}, {"Y": 4041070.453097}, {"Z": 55.762826}, {"X": 344271.628996}, {"Y": 4041070.561097}, {"Z": 55.761226}, {"X": 344271.442995}, {"Y": 4041070.620597}, {"Z": 55.760626}, {"X": 344271.084595}, {"Y": 4041070.766697}, {"Z": 55.763227}, {"X": 344268.967696}, {"Y": 4041071.607797}, {"Z": 55.755127}, {"X": 344268.058396}, {"Y": 4041071.966397}, {"Z": 55.751826}, {"X": 344266.558695}, {"Y": 4041072.572497}, {"Z": 55.736227}, {"X": 344263.770487}, {"Y": 4041073.679526}, {"Z": 55.716624}, {"X": 344263.457996}, {"Y": 4041073.803597}, {"Z": 55.714426}, {"X": 344262.137395}, {"Y": 4041074.318097}, {"Z": 55.702026}, {"X": 344261.045096}, {"Y": 4041074.758397}, {"Z": 55.692126}, {"X": 344259.625195}, {"Y": 4041075.322897}, {"Z": 55.683827}, {"X": 344258.515995}, {"Y": 4041075.760297}, {"Z": 55
# ...

# %%
#json형식으로 변환 3.
# Out:
# list

# %%
an =[]
for i in range(len(kv)//3):
    an.append()
    for j in range():

# %%
con = json.dumps(linet, sort_keys=True,  ensure_ascii=False)



type(con)
# Out:
# str

# %%
#json파일 저장하는법

with open("C:/Users/ParkJinSeok/Desktop/학습자료/jsf","w") as j:
    j.write(json.)

# %%
import json
from collections import OrderedDict

file_data = OrderedDict()

file_data["name"] = "Link"
file_data["coordinate"] = {kv[0]:vv[0]}

file_data["coordinate"].add("b")
print(json.dumps(file_data, ensure_ascii=False, indent="\t"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-82268d2cb88a> in <module>
#       7 file_data["coordinate"] = {kv[0]:vv[0]}
#       8
# ----> 9 file_data["coordinate"].add("b")
#      10 print(json.dumps(file_data, ensure_ascii=False, indent="\t"))
#
# AttributeError: 'dict' object has no attribute 'add'
